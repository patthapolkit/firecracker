# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Fibo Recursive

# %%
n_values = list(range(1, 30))

# %%
times_1 =[4.76837158203125e-07, 7.152557373046875e-07, 8.106231689453125e-07, 1.3828277587890625e-06, 1.9073486328125e-06, 3.0517578125e-06, 5.674362182617188e-06, 8.106231689453125e-06, 1.2969970703125e-05, 2.1028518676757813e-05, 3.690719604492188e-05, 5.593299865722656e-05, 9.036064147949219e-05, 0.00014400482177734375, 0.00023245811462402344, 0.0003804206848144531, 0.0006205558776855469, 0.0009950160980224609, 0.0016266822814941407, 0.002603292465209961, 0.004214429855346679, 0.006784915924072266, 0.011028861999511719, 0.017931222915649414, 0.02912735939025879, 0.04722471237182617, 0.07570881843566894, 0.1226412296295166, 0.19869537353515626]

# %%
times_2 = [4.291534423828125e-07, 5.245208740234375e-07, 3.814697265625e-07, 5.245208740234375e-07, 6.198883056640625e-07, 8.58306884765625e-07, 1.3828277587890625e-06, 2.288818359375e-06, 3.862380981445312e-06, 5.102157592773437e-06, 8.630752563476563e-06, 1.3971328735351563e-05, 2.2125244140625e-05, 3.604888916015625e-05, 6.361007690429688e-05, 9.46044921875e-05, 0.00014357566833496095, 0.0002323150634765625, 0.0004292011260986328, 0.0006367683410644532, 0.0009477138519287109, 0.001432323455810547, 0.002315187454223633, 0.0038257598876953124, 0.006043910980224609, 0.009778499603271484, 0.016260671615600585, 0.026476478576660155, 0.04659719467163086]

# %%
rasp = [1.0013580322265625e-06, 1.3828277587890625e-06, 1.239776611328125e-06, 1.52587890625e-06, 2.384185791015625e-06, 3.719329833984375e-06, 5.9604644775390625e-06, 9.250640869140624e-06, 1.4591217041015626e-05, 2.3746490478515624e-05, 3.795623779296875e-05, 6.289482116699219e-05, 0.00010051727294921876, 0.0001605987548828125, 0.0002652645111083984, 0.0004195690155029297, 0.0006838798522949219, 0.001106405258178711, 0.0017837047576904296, 0.002898120880126953, 0.004672431945800781, 0.007561826705932617, 0.01221919059753418, 0.019820785522460936, 0.03209218978881836, 0.05193376541137695, 0.08422226905822754, 0.13621268272399903, 0.2206289291381836]

# %%
fire = [1.7642974853515626e-06, 2.3365020751953127e-06, 2.0503997802734374e-06, 2.9087066650390623e-06, 8.821487426757812e-06, 7.05718994140625e-06, 1.10626220703125e-05, 2.0742416381835938e-05, 2.8896331787109376e-05, 6.880760192871094e-05, 7.510185241699219e-05, 0.00012793540954589844, 0.00019583702087402343, 0.0003174781799316406, 0.0005246639251708984, 0.000850057601928711, 0.0013913154602050782, 0.0022617340087890624, 0.0036821842193603517, 0.0059490203857421875, 0.00956869125366211, 0.015346908569335937, 0.024749279022216797, 0.03983745574951172, 0.06385159492492676, 0.10390572547912598, 0.1687685489654541, 0.27277402877807616, 0.4437523365020752]

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_values, rasp, label='Raspberry Pi')
plt.plot(n_values, fire, label='Firecracker')
plt.xlabel('n')
plt.ylabel('Execution Time (s)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Fibo DP

# %%
n = 500000

# %%
n_values = list(range(1, n+1))

# %%
with open(f'results_c/{n}/results_rasp.txt', 'r') as f:
    rasp = f.readlines()
    n_values_rasp = [int(x.strip().split(',')[0]) for x in rasp]
    times_rasp = [float(x.strip().split(',')[1]) for x in rasp]

with open(f'results_c/{n}/results_fire.txt', 'r') as f:
    fire = f.readlines()
    n_values_fire = [int(x.strip().split(',')[0]) for x in fire]
    times_fire = [float(x.strip().split(',')[1]) for x in fire]

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_values, times_fire, label='Firecracker')
plt.plot(n_values, times_rasp, label='Raspberry Pi')
plt.title('fibonacci o(n)') 
plt.xlabel('n')
plt.ylabel('Execution Time (s)')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(n_values, times_rasp, label='Raspberry Pi')
plt.title('fibonacci o(n)') 
plt.xlabel('n')
plt.ylabel('Execution Time (s)')
plt.legend()
plt.grid(True)
plt.show()
